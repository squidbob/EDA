# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("2015.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isna().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Standard Error                   False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(data=df, x="Happiness Score", y="Health (Life Expectancy)", hue="Region")
plt.legend(bbox_to_anchor=(1.7, 0.5), loc="right", title="Region")

# %%
westeur=df.loc[df["Region"]=="Western Europe"]
sahara=df.loc[df["Region"]=="Sub-Saharan Africa"]
westeur_sahara=pd.concat([westeur, sahara], axis=0)
westeur_sahara
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1         Iceland      Western Europe               2            7.561
# 2         Denmark      Western Europe               3            7.527
# 3          Norway      Western Europe               4            7.522
# 5         Finland      Western Europe               6            7.406
# ..            ...                 ...             ...              ...
# 151  Burkina Faso  Sub-Saharan Africa             152            3.587
# 153        Rwanda  Sub-Saharan Africa             154            3.465
# 154         Benin  Sub-Saharan Africa             155            3.340
# 156       Burundi  Sub-Saharan Africa             157            2.905
# 157          Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
sns.histplot(data=westeur_sahara, x="Dystopia Residual", hue="Region", element="poly")
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Family", y="Region")
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Region'>

# %%
happiness=df.iloc[: , 5:]
happiness
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
sns.heatmap(happiness.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df, x="Freedom", y="Generosity", hue="Region")
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Generosity'>

# %%
sns.histplot(data=westeur_sahara, x="Freedom", hue="Region", element="poly")
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Count'>

# %%
sns.histplot(data=westeur_sahara, x="Generosity", hue="Region", element="poly")
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Count'>

# %%
fig,axs=plt.subplots(ncols=2)
sns.histplot(data=westeur_sahara, x="Freedom", hue="Region", element="poly", ax=axs[0])
sns.histplot(data=westeur_sahara, x="Generosity", hue="Region", element="poly", ax=axs[1])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Count'>
